# %%
import numpy as np
import matplotlib
import xarray as xr
import cartopy
import torch

# %% [markdown]
# If you see a ModuleNotFoundError below, then a package was not successfull installed.

# %%
print("NumPy:", np.__version__)
print("Matplotlib:", matplotlib.__version__)
print("Xarray:", xr.__version__)
print("Cartopy:", cartopy.__version__)
print("PyTorch:", torch.__version__)
print("Packages imported successfully!")
# Out:
# NumPy: 2.4.3
# Matplotlib: 3.10.9
# Xarray: 2026.4.0
# Cartopy: 0.25.0
# PyTorch: 2.10.0
# Packages imported successfully!
